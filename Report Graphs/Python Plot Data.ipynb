# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
distance = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

Seven_Low = [-62, -67, -66, -71, -80, -72, -78, -79, -78, -76]
Seven_Medium = [-62, -72, -66, -68, -79, -73, -80, -80, -79, -77]
Seven_High = [-63, -74, -70, -72, -80, -75, -83, -81, -79, -77]

Eight_Low = [-63, -67, -66, -68, -78, -71, -82, -78, -77, -77]
Eight_Medium = [-65, -70, -67, -70, -79, -72, -82, -78, -84, -77] 
Eight_High = [-67, -71, -67, -70, -82, -74, -84, -79, -84, -79]

Nine_Low = [-63, -68, -67, -68, -78, -71, -81, -79, -77, -77]
Nine_Medium = [-65, -70, -67, -70, -77, -72, -84, -80, -83, -77] 
Nine_High = [-65, -72, -69, -71, -79, -73, -86, -80, -97, -83]

Ten_Low = [-63, -67, -65, -67, -76, -70, -81, -77, -81, -75]
Ten_Medium = [-64, -70, -65, -67, -77, -72, -83, -78, -83, -76]
Ten_High = [-67, -70, -67, -68, -77, -72, -84, -79, -94, -77]

Eleven_Low = [-63, -67, -65, -67, -76, -71, -81, -77, -76, -75]
Eleven_Medium = [-67, -68, -66, -67, -77, -71, -84, -77, -78, -76]
Eleven_High = [-71, -70, -66, -69, -78, -72, -84, -81, -82, -82]

Twelve_Low = [-64, -68, -65, -67, -78, -72, -83, -80, -77, -77]
Twelve_Medium = [-66, -70, -67, -68, -77, -72, -83, -82, -80, -77]
Twelve_High = [-71, -75, -68, -68, -80, -73, -84, -83, -82, -79]

# %%
plt.plot(distance, Seven_Low, color='r', label='1200 bps')
plt.plot(distance, Seven_Medium, color='g', label='3000 bps')
plt.plot(distance, Seven_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 7")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Eight_Low, color='r', label='1200 bps')
plt.plot(distance, Eight_Medium, color='g', label='3000 bps')
plt.plot(distance, Eight_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 8")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Nine_Low, color='r', label='1200 bps')
plt.plot(distance, Nine_Medium, color='g', label='3000 bps')
plt.plot(distance, Nine_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 9")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Ten_Low, color='r', label='1200 bps')
plt.plot(distance, Ten_Medium, color='g', label='3000 bps')
plt.plot(distance, Ten_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 10")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Eleven_Low, color='r', label='1200 bps')
plt.plot(distance, Eleven_Medium, color='g', label='3000 bps')
plt.plot(distance, Eleven_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 11")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Twelve_Low, color='r', label='1200 bps')
plt.plot(distance, Twelve_Medium, color='g', label='3000 bps')
plt.plot(distance, Twelve_High, color='b', label='3800 bps')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 12")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(distance, Seven_Low, color='green', label='7')          #WORST
plt.plot(distance, Eight_Low, color='orange', label='8')       
plt.plot(distance, Nine_Low, color='royalblue', label='9')     
plt.plot(distance, Ten_Low, color='gold', label='10')          
plt.plot(distance, Eleven_Low, color='tomato', label='11')       #BEST
plt.plot(distance, Twelve_Low, color='darkorchid', label='12')   #WORST

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI for all Spreading Factors")

# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
import pandas as pd
from datetime import time
import matplotlib.dates as mdates

my_day = datetime.date(2021, 10, 22)

plt.figure(figsize=(13, 10), dpi=80)
TIME_TWELVE = [datetime.datetime.combine(my_day, time(12,33,23,55)) ,datetime.datetime.combine(my_day, time(12,34,33,15)) ,datetime.datetime.combine(my_day, time(12,36,36,932)) ,datetime.datetime.combine(my_day, time(12,49,23,55)), datetime.datetime.combine(my_day, time(12,49,33,15)), datetime.datetime.combine(my_day, time(12,49,36,932)), datetime.datetime.combine(my_day, time(12,50,24,127)) ,datetime.datetime.combine(my_day, time(12,50,34,43)), datetime.datetime.combine(my_day, time(12,50,44,175)) ,datetime.datetime.combine(my_day, time(12,52,26,181)) ,datetime.datetime.combine(my_day, time(12,52,36,112)) ,datetime.datetime.combine(my_day, time(13,3,37,587)) ,datetime.datetime.combine(my_day, time(13,3,47,532)) ,datetime.datetime.combine(my_day, time(13,4,38,627)), datetime.datetime.combine(my_day, time(13,4,48,582)), datetime.datetime.combine(my_day, time(13,5,49,638)), datetime.datetime.combine(my_day, time(13,5,59,735)) , datetime.datetime.combine(my_day, time(13,6,50,647)) , datetime.datetime.combine(my_day, time(13,6,40,724))]
TWELVE = np.array([-149,-147,-151,-127,-130, -131, -127, -125, -126, -130, -123, -111, -110, -116, -119, -118, -120, -112, -118])
plt.xticks(rotation=90)
size_Twelve = np.array([300,300,300, 150, 150, 150, 150, 150, 150, 150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_TWELVE, TWELVE, s=size_Twelve, label='12')


TIME_ELEVEN = [datetime.datetime.combine(my_day, time(12,50,50,375)) ,datetime.datetime.combine(my_day, time(12,50,54,524)) ,datetime.datetime.combine(my_day, time(12,50,58,757)) ,datetime.datetime.combine(my_day, time(12,52,52,465)) ,datetime.datetime.combine(my_day, time(12,52,56,596)) ,datetime.datetime.combine(my_day, time(13,4,3,882)) ,datetime.datetime.combine(my_day, time(13,4,8,32)) ,datetime.datetime.combine(my_day, time(13,5,4,942)) ,datetime.datetime.combine(my_day, time(13,5,13,274)) ,datetime.datetime.combine(my_day, time(13,6,5,985)) ,datetime.datetime.combine(my_day, time(13,6,10,118)) ,datetime.datetime.combine(my_day, time(13,7,11,151)), datetime.datetime.combine(my_day, time(13,7,15,378))]
ELEVEN = np.array([-124,-127,-124, -124, -122, -110, -111, -120, -119, -121, -119, -118, -119])
plt.xticks(rotation=60)
size_Eleven = np.array([150,150,150, 150, 150 ,50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_ELEVEN, ELEVEN, s=size_Eleven ,label='11')


TIME_TEN = [datetime.datetime.combine(my_day, time(12,51,1,306)) ,datetime.datetime.combine(my_day, time(12,51,3,290)) ,datetime.datetime.combine(my_day, time(12,51,5,408)) ,datetime.datetime.combine(my_day, time(12,53,5,378)) ,datetime.datetime.combine(my_day, time(12,53,7,483)) ,datetime.datetime.combine(my_day, time(13,4,16,812))  ,datetime.datetime.combine(my_day, time(13,4,18,871))  ,datetime.datetime.combine(my_day, time(13,5,15,847)) ,datetime.datetime.combine(my_day, time(13,5,19,906)) ,datetime.datetime.combine(my_day, time(13,6,16,905)) ,datetime.datetime.combine(my_day, time(13,6,20,973)) ,datetime.datetime.combine(my_day, time(13,7,17,942)) ,datetime.datetime.combine(my_day, time(13,7,19,912))]
TEN = np.array([-127,-129,-131, -125 ,-127, -115, -114, -120, -119, -121, -122, -118, -119])
plt.xticks(rotation=60)
size_Ten = np.array([150, 150, 150, 150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_TEN, TEN, s=size_Ten, label='10')


TIME_NINE = [datetime.datetime.combine(my_day, time(12,51,9,45))   ,datetime.datetime.combine(my_day, time(12,53,9,28)) ,datetime.datetime.combine(my_day, time(13,4,20,429)) ,datetime.datetime.combine(my_day, time(13,4,21,995)) ,datetime.datetime.combine(my_day, time(13,5,21,475)) ,datetime.datetime.combine(my_day, time(13,5,23,6)) ,datetime.datetime.combine(my_day, time(13,6,22,505)) ,datetime.datetime.combine(my_day, time(13,6,24,24)) ,datetime.datetime.combine(my_day, time(13,7,25,83)) ,datetime.datetime.combine(my_day, time(13,7,26,627))]
NINE = np.array([-130, -128, -113, -114, -119, -120, -122, -122, -120, -118])
plt.xticks(rotation=60)
size_Nine = np.array([150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_NINE, NINE, s=size_Nine, label='9', color = 'gray')


TIME_EIGHT = [datetime.datetime.combine(my_day, time(13,4,24,867)), datetime.datetime.combine(my_day, time(13,4,26,134)), datetime.datetime.combine(my_day, time(13,5,25,888)) ,datetime.datetime.combine(my_day, time(13,5,28,538)) ,datetime.datetime.combine(my_day, time(13,6,26,924)) ,datetime.datetime.combine(my_day, time(13,6,29,549)) ,datetime.datetime.combine(my_day, time(13,7,27,959)) ,datetime.datetime.combine(my_day, time(13,7,30,598))]
EIGHT = np.array([-110, -110, -119, -119, -121, -120, -118, -119])
plt.xticks(rotation=60)
size_Eight = np.array([50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_EIGHT, EIGHT, s=size_Eight, label='8', color = 'cyan')


TIME_SEVEN = [datetime.datetime.combine(my_day, time(13,4,28,678)) ,datetime.datetime.combine(my_day, time(13,4,30,978)) ,datetime.datetime.combine(my_day, time(13,5,29,672)) ,datetime.datetime.combine(my_day, time(13,5,30,863)) ,datetime.datetime.combine(my_day, time(13,6,30,749)) ,datetime.datetime.combine(my_day, time(13,6,33,65)) ,datetime.datetime.combine(my_day, time(13,7,31,781)) ,datetime.datetime.combine(my_day, time(13,7,32,917))]
SEVEN = np.array([-115, -111, -120, -121, -118, -120, -118, -119])
plt.xticks(rotation=60)
size_Seven = np.array([50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_SEVEN, SEVEN, s=size_Seven, label='7', color = 'hotpink')


plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M:%S')
plt.gca().xaxis.set_major_formatter(myFmt)
plt.legend()

plt.xlabel("Time")
plt.ylabel("RSSI [dbm]")
plt.title("Long Distance Test Showing LoRa Parameters in Different Weather Conditions")

plt.show()

# %%
my_day = datetime.date(2021, 10, 22)

plt.figure(figsize=(13, 10), dpi=80)
TIME_TWELVE = [datetime.datetime.combine(my_day, time(12,33,23,55)) ,datetime.datetime.combine(my_day, time(12,34,33,15)) ,datetime.datetime.combine(my_day, time(12,36,36,932)) ,datetime.datetime.combine(my_day, time(12,49,23,55)), datetime.datetime.combine(my_day, time(12,49,33,15)), datetime.datetime.combine(my_day, time(12,49,36,932)), datetime.datetime.combine(my_day, time(12,50,24,127)) ,datetime.datetime.combine(my_day, time(12,50,34,43)), datetime.datetime.combine(my_day, time(12,50,44,175)) ,datetime.datetime.combine(my_day, time(12,52,26,181)) ,datetime.datetime.combine(my_day, time(12,52,36,112)) ,datetime.datetime.combine(my_day, time(13,3,37,587)) ,datetime.datetime.combine(my_day, time(13,3,47,532)) ,datetime.datetime.combine(my_day, time(13,4,38,627)), datetime.datetime.combine(my_day, time(13,4,48,582)), datetime.datetime.combine(my_day, time(13,5,49,638)), datetime.datetime.combine(my_day, time(13,5,59,735)) , datetime.datetime.combine(my_day, time(13,6,50,647)) , datetime.datetime.combine(my_day, time(13,6,40,724))]
TWELVE = np.array([-149,-147,-151,-127,-130, -131, -127, -125, -126, -130, -123, -111, -110, -116, -119, -118, -120, -112, -118])
plt.xticks(rotation=90)
size_Twelve = np.array([300,300,300, 150, 150, 150, 150, 150, 150, 150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.bar(TIME_TWELVE, TWELVE, label='12')


TIME_ELEVEN = [datetime.datetime.combine(my_day, time(12,50,50,375)) ,datetime.datetime.combine(my_day, time(12,50,54,524)) ,datetime.datetime.combine(my_day, time(12,50,58,757)) ,datetime.datetime.combine(my_day, time(12,52,52,465)) ,datetime.datetime.combine(my_day, time(12,52,56,596)) ,datetime.datetime.combine(my_day, time(13,4,3,882)) ,datetime.datetime.combine(my_day, time(13,4,8,32)) ,datetime.datetime.combine(my_day, time(13,5,4,942)) ,datetime.datetime.combine(my_day, time(13,5,13,274)) ,datetime.datetime.combine(my_day, time(13,6,5,985)) ,datetime.datetime.combine(my_day, time(13,6,10,118)) ,datetime.datetime.combine(my_day, time(13,7,11,151)), datetime.datetime.combine(my_day, time(13,7,15,378))]
ELEVEN = np.array([-124,-127,-124, -124, -122, -110, -111, -120, -119, -121, -119, -118, -119])
plt.xticks(rotation=60)
size_Eleven = np.array([150,150,150, 150, 150 ,50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.bar(TIME_ELEVEN, ELEVEN ,label='11')


TIME_TEN = [datetime.datetime.combine(my_day, time(12,51,1,306)) ,datetime.datetime.combine(my_day, time(12,51,3,290)) ,datetime.datetime.combine(my_day, time(12,51,5,408)) ,datetime.datetime.combine(my_day, time(12,53,5,378)) ,datetime.datetime.combine(my_day, time(12,53,7,483)) ,datetime.datetime.combine(my_day, time(13,4,16,812))  ,datetime.datetime.combine(my_day, time(13,4,18,871))  ,datetime.datetime.combine(my_day, time(13,5,15,847)) ,datetime.datetime.combine(my_day, time(13,5,19,906)) ,datetime.datetime.combine(my_day, time(13,6,16,905)) ,datetime.datetime.combine(my_day, time(13,6,20,973)) ,datetime.datetime.combine(my_day, time(13,7,17,942)) ,datetime.datetime.combine(my_day, time(13,7,19,912))]
TEN = np.array([-127,-129,-131, -125 ,-127, -115, -114, -120, -119, -121, -122, -118, -119])
plt.xticks(rotation=60)
size_Ten = np.array([150, 150, 150, 150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_TEN, TEN, s=size_Ten, label='10')


TIME_NINE = [datetime.datetime.combine(my_day, time(12,51,9,45))   ,datetime.datetime.combine(my_day, time(12,53,9,28)) ,datetime.datetime.combine(my_day, time(13,4,20,429)) ,datetime.datetime.combine(my_day, time(13,4,21,995)) ,datetime.datetime.combine(my_day, time(13,5,21,475)) ,datetime.datetime.combine(my_day, time(13,5,23,6)) ,datetime.datetime.combine(my_day, time(13,6,22,505)) ,datetime.datetime.combine(my_day, time(13,6,24,24)) ,datetime.datetime.combine(my_day, time(13,7,25,83)) ,datetime.datetime.combine(my_day, time(13,7,26,627))]
NINE = np.array([-130, -128, -113, -114, -119, -120, -122, -122, -120, -118])
plt.xticks(rotation=60)
size_Nine = np.array([150, 150, 50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_NINE, NINE, s=size_Nine, label='9', color = 'gray')


TIME_EIGHT = [datetime.datetime.combine(my_day, time(13,4,24,867)), datetime.datetime.combine(my_day, time(13,4,26,134)), datetime.datetime.combine(my_day, time(13,5,25,888)) ,datetime.datetime.combine(my_day, time(13,5,28,538)) ,datetime.datetime.combine(my_day, time(13,6,26,924)) ,datetime.datetime.combine(my_day, time(13,6,29,549)) ,datetime.datetime.combine(my_day, time(13,7,27,959)) ,datetime.datetime.combine(my_day, time(13,7,30,598))]
EIGHT = np.array([-110, -110, -119, -119, -121, -120, -118, -119])
plt.xticks(rotation=60)
size_Eight = np.array([50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_EIGHT, EIGHT, s=size_Eight, label='8', color = 'cyan')


TIME_SEVEN = [datetime.datetime.combine(my_day, time(13,4,28,678)) ,datetime.datetime.combine(my_day, time(13,4,30,978)) ,datetime.datetime.combine(my_day, time(13,5,29,672)) ,datetime.datetime.combine(my_day, time(13,5,30,863)) ,datetime.datetime.combine(my_day, time(13,6,30,749)) ,datetime.datetime.combine(my_day, time(13,6,33,65)) ,datetime.datetime.combine(my_day, time(13,7,31,781)) ,datetime.datetime.combine(my_day, time(13,7,32,917))]
SEVEN = np.array([-115, -111, -120, -121, -118, -120, -118, -119])
plt.xticks(rotation=60)
size_Seven = np.array([50, 50, 50, 50, 50, 50, 50, 50])
plt.plot([],[])
plt.scatter(TIME_SEVEN, SEVEN, s=size_Seven, label='7', color = 'hotpink')


plt.gcf().autofmt_xdate()
myFmt = mdates.DateFormatter('%H:%M:%S')
plt.gca().xaxis.set_major_formatter(myFmt)
plt.legend()

plt.xlabel("Time")
plt.ylabel("RSSI [dbm]")
plt.title("Long Distance Test Showing LoRa Parameters in Different Weather Conditions")

plt.show()

# %%
Twelve_Long = [-76, -79, -76, -78, -89, -81, -91, -90, -89, -87]
Eleven_Long = [-73, -78, -74, -76, -86, -79, -93, -88, -88, -84]
Ten_Long = [-73, -78, -75, -76, -84, -79, -90, -87, -95, -90]
Nine_Long = [-73, -79, -76, -77, -87, -80, -90, -87, -105, -88]
Eight_Long = [-67, -74, -71, -74, -82, -76, -88, -82, -88, -80]
Seven_Long = [-64, -75, -71, -76, -83, -76, -86, -84, -84, -81]

# %%
plt.plot(distance, Twelve_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Twelve_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 12 for Different Payload Sizes")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Eleven_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Eleven_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 11 for Different Payload Sizes")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Ten_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Ten_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 10 for Different Payload Sizes")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Nine_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Nine_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 9 for Different Payload Sizes")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Eight_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Eight_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 8 for Different Payload Sizes")

# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
plt.plot(distance, Seven_Low, color='darkorange', label='88 Bytes')
plt.plot(distance, Seven_Long, color='royalblue', label='3 Bytes')

plt.xlabel("Distance [m]")
plt.ylabel("RSSI [dbm]")
plt.title("Distance vs RSSI of SF = 7 for Different Payload Sizes")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
x = np.array([50, 100, 150, 200, 250, 300, 350, 400, 450, 500])
y = np.array([-64, -68, -65, -67, -78, -72, -83, -80, -77, -77])

plt.scatter(x, y)
plt.show()
#fit the model
fit = np.polyfit(x, np.log(y), 1)

#view the output of the model
print(fit)
# Out:
# C:\Users\yashi\anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log
#   import sys
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-25-7859facf7ed1> in <module>
#       5 plt.show()
#       6 #fit the model
# ----> 7 fit = np.polyfit(x, np.log(y), 1)
#       8
#       9 #view the output of the model
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     629     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     630     lhs /= scale
# --> 631     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     632     c = (c.T/scale).T  # broadcast scale coefficients
#     633
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in lstsq(a, b, rcond)
# ...
